# %%
# import os, shutil

# # @article{abolghasemi2018incoherent,
# #   title={Incoherent dictionary pair learning: Application to a novel open-source database of chinese numbers},
# #   author={Abolghasemi, Vahid and Chen, Mingyang and Alameer, Ali and Ferdowsi, Saideh and Chambers, Jonathon and Nazarpour, Kianoush},
# #   journal={IEEE Signal Processing Letters},
# #   volume={25},
# #   number={4},
# #   pages={472--476},
# #   year={2018},
# #   publisher={IEEE}
# # }

# destination_dir = '/Users/vinodkumar/Downloads/ChineseNumbers/'
# source_dir = '/Users/vinodkumar/Downloads/CN/'

# files = os.listdir(source_dir)

# # for i in range(1, 16):
# #     os.mkdir(destination_dir + f'{i}')

# for f in files:
#     print(f)
#     if 'Locate' not in f:
#         continue
#     digit = f.replace('Locate{','').replace('}.jpg','').split(',')[2]
#     print(os.path.join(source_dir, f), destination_dir + digit + '/' + f)
#     shutil.move(os.path.join(source_dir, f), destination_dir + digit + '/' + f)

import os, shutil

destination_dir = '/Users/vinodkumar/Downloads/archive/AC/Train/'
source_dir = '/Users/vinodkumar/Downloads/archive/train/'

files = os.listdir(source_dir)

# for i in range(1, 16):
#     os.mkdir(destination_dir + f'{i}')

for f in files:
    print(f)
    if '.png' not in f:
        continue
    digit = f.replace('.png','').split('_')[-1]
    print(os.path.join(source_dir, f), destination_dir + digit + '/' + f)
    if os.path.exists(destination_dir + digit + '/'):
        shutil.move(os.path.join(source_dir, f), destination_dir + digit + '/' + f)
    else:
        os.makedirs(destination_dir + digit + '/')
        shutil.move(os.path.join(source_dir, f), destination_dir + digit + '/' + f)
# Out:
# id_7752_label_17.png
# /Users/vinodkumar/Downloads/archive/train/id_7752_label_17.png /Users/vinodkumar/Downloads/archive/AC/Train/17/id_7752_label_17.png
# id_4930_label_1.png
# /Users/vinodkumar/Downloads/archive/train/id_4930_label_1.png /Users/vinodkumar/Downloads/archive/AC/Train/1/id_4930_label_1.png
# id_9968_label_14.png
# /Users/vinodkumar/Downloads/archive/train/id_9968_label_14.png /Users/vinodkumar/Downloads/archive/AC/Train/14/id_9968_label_14.png
# id_3085_label_22.png
# /Users/vinodkumar/Downloads/archive/train/id_3085_label_22.png /Users/vinodkumar/Downloads/archive/AC/Train/22/id_3085_label_22.png
# id_12410_label_12.png
# /Users/vinodkumar/Downloads/archive/train/id_12410_label_12.png /Users/vinodkumar/Downloads/archive/AC/Train/12/id_12410_label_12.png
# id_12320_label_28.png
# /Users/vinodkumar/Downloads/archive/train/id_12320_label_28.png /Users/vinodkumar/Downloads/archive/AC/Train/28/id_12320_label_28.png
# id_3822_label_2.png
# /Users/vinodkumar/Downloads/archive/train/id_3822_label_2.png /Users/vinodkumar/Downloads/archive/AC/Train/2/id_3822_label_2.png
# id_10679_label_19.png
# /Users/vinodkumar/Downloads/archive/train/id_10679_label_19.png /Users/vinodkumar/Downloads/archive/AC/Train/19/id_10679_label_19.png
# id_10431_label_16.png
# /Users/vinodkumar/Downloads/archive/train/id_10431_label_16.png /Users/vinodkumar/Downloads/archive/AC/Train/16/id_10431_label_16.png
# id_9313_label_17.png
# /Users/vinodkumar/Downloads/archive/train/id_9313_label_17.png /Users/vinodkumar/Downloads/archive/AC/Train/17/id_9313_label_17.png
# id_8951_label_27.png
# /Users/vinodkumar/Downloads/archive/train/id_8951_label_27.png /Users/vinodkumar/Downloads/archive/AC/Train/27/id_8951_label_27.png
# id_13104_label_14.png
# /Users/vinodkumar/Downloads/archive/train/id_13104_label_14.png /Users/vinodkumar/Downloads/archive/AC/Train/14/id_13104_label_14.png
# id_6829_label_14.png
# /Users/vinodkumar/Downloads/archive/train/id_6829_label_14.png /Users/vinodkumar/Downloads/archive/AC/Train/14/id_6829_label_14.png
# id_8646_label_17.png
# /Users/vinodkumar/Downloads/archive/train/id_8646_label_17.png /Users/vinodkumar/Downloads/archive/AC/Train/17/id_8646_label_17.png
# id_3808_label_28.png
# /Users/vinodkumar/Downloads/archive/train/id_3808_label_28.png /Users/vinodkumar/Downloads/archive/AC/Train/28/id_3808_label_28.png
# id_2614_label_19.png
# /Users/vinodkumar/Downloads/archive/train/id_2614_label_19.png /Users/vinodkumar/Downloads/archive/AC/Train/19/id_2614_label_19.png
# id_985_label_12.png
# /Users/vinodkumar/Downloads/archive/train/id_985_label_12.png /Users/vinodkumar/Downloads/archive/AC/Train/12/id_985_label_12.png
# id_13137_label_19.png
# /Users/vinodkumar/Downloads/archive/train/id_13137_label_19.png /Users/vinodkumar/Downloads/archive/AC/Train/19/id_13137_label_19.png
# id_11445_label_3.png
# /Users/vinodkumar/Downloads/archive/train/id_11445_label_3.png /Users/vinodkumar/Downloads/archive/AC/Train/3/id_11445_label_3.png
# id_3421_label_8.png
# /Users/vinodkumar/Downloads/archive/train/id_3421_label_8.png /Users/vinodkumar/Downloads/archive/AC/Train/8/id_3421_label_8.png
# id_11865_label_28.png
# /Users/vinodkumar/Downloads/archive/train/id_11865_label_28.png /Users/vinodkumar/Downloads/archive/AC/Train/28/id_11865_label_28.png
# id_2536_label_9.png
# /Users/vinodkumar/Downloads/archive/train/id_2536_label_9.png /Users/vinodkumar/Downloads/archive/AC/Train/9/id_2536_label_9.png
# id_5043_label_15.png
# /Users/vinodkumar/Downloads/archive/train/id_5043_label_15.png /Users/vinodkumar/Downloads/archive/AC/Train/15/id_5043_label_15.png
# id_1422_label_10.png
# /Users/vinodkumar/Downloads/archive/train/id_1422_label_10.png /Users/vinodkumar/Downloads/archive/AC/Train/10/id_1422_label_10.png
# id_9489_label_11.png
# /Users/vinodkumar/Downloads/archive/train/id_9489_label_11.png /Users/vinodkumar/Downloads/archive/AC/Train/11/id_9489_label_11.png
# id_7076_label_17.png
# /Users/vinodkumar/Downloads/archive/train/id_7076_label_17.png /Users/vinodkumar/Downloads/archive/AC/Train/17/id_7076_label_17.png
# id_8063_label_28.png
# /Users/vinodkumar/Downloads/archive/train/id_8063_label_28.png /Users/vinodkumar/Downloads/archive/AC/Train/28/id_8063_label_28.png
# id_9795_label_21.png
# /Users/vinodkumar/Downloads/archive/train/id_9795_label_21.png /Users/vinodkumar/Downloads/archive/AC/Train/21/id_9795_label_21.png
# id_4184_label_19.png
# /Users/vinodkumar/Downloads/archive/train/id_4184_label_19.png /Users/vinodkumar/Downloads/archive/AC/Train/19/id_4184_label_19.png
# id_8522_label_2.png
# /Users/vinodkumar/Downloads/archive/train/id
# 199/199 [==============================] - 46s 229ms/step - loss: 0.2416 - accuracy: 0.9173 - val_loss: 0.6680 - val_accuracy: 0.7636 - lr: 1.0000e-04
# Epoch 4/30
# 199/199 [==============================] - 43s 217ms/step - loss: 0.2090 - accuracy: 0.9321 - val_loss: 0.6265 - val_accuracy: 0.7798 - lr: 1.0000e-04
# Epoch 5/30
# 199/199 [==============================] - 44s 220ms/step - loss: 0.1814 - accuracy: 0.9391 - val_loss: 0.6057 - val_accuracy: 0.7899 - lr: 1.0000e-04
# Epoch 6/30
# 199/199 [==============================] - 61s 305ms/step - loss: 0.1356 - accuracy: 0.9531 - val_loss: 0.4835 - val_accuracy: 0.8273 - lr: 5.0000e-05
# Epoch 7/30
# 199/199 [==============================] - 46s 230ms/step - loss: 0.1264 - accuracy: 0.9580 - val_loss: 0.6016 - val_accuracy: 0.8010 - lr: 5.0000e-05
# Epoch 8/30
# 199/199 [==============================] - 43s 216ms/step - loss: 0.1066 - accuracy: 0.9657 - val_loss: 0.6005 - val_accuracy: 0.7970 - lr: 5.0000e-05
# Epoch 9/30
# 199/199 [==============================] - 46s 230ms/step - loss: 0.1043 - accuracy: 0.9672 - val_loss: 0.5620 - val_accuracy: 0.8101 - lr: 5.0000e-05
# Epoch 10/30
# 199/199 [==============================] - 44s 220ms/step - loss: 0.1008 - accuracy: 0.9674 - val_loss: 0.5716 - val_accuracy: 0.8091 - lr: 5.0000e-05
# Epoch 11/30
# 199/199 [==============================] - 40s 198ms/step - loss: 0.0961 - accuracy: 0.9676 - val_loss: 0.5486 - val_accuracy: 0.8343 - lr: 5.0000e-05
# Epoch 12/30
# 199/199 [==============================] - 35s 177ms/step - loss: 0.0876 - accuracy: 0.9696 - val_loss: 0.5508 - val_accuracy: 0.8212 - lr: 5.0000e-05
# Epoch 13/30
# 187/199 [===========================>..] - ETA: 1s - loss: 0.0889 - accuracy: 0.9698

# %%
# HCR-Net (fine tuned network)
import numpy as np
import math
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import f1_score, precision_score, recall_score, accuracy_score

# %matplotlib inline

import tensorflow as tf
from tensorflow import keras
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Dropout, Flatten, Dense
from keras.layers import BatchNormalization as BatchNorm

# pre-trained models
from keras.applications.vgg16 import VGG16

# custom learning rates
import learning_rate as lr

# set the seeds for reproduceability (which is not certain in case of
# of multiple CPUs and GPU).
np.random.seed(1)
tf.random.set_seed(1)

# change following for each dataset (dataset details and learning params)
# dataset details
train_data_dir = '/Users/vinodkumar/Downloads/ChineseNumbers/'
nb_train_samples = 6375
nb_validation_samples = 1125
num_classes = 15

# learning params
epochs1 = 30
epochs2 = 20
learning_rate1 = lr.decayed_learning_rate
learning_rate2 = lr.decayed_learning_rate_tuned20

batch_size = 32
# dimensions of our images.
img_width, img_height = 32, 32
input_shape = (img_width, img_height, 3)

# using VGG16: load model without classifier layer, and using weights from ImageNet
source_model = VGG16(include_top=False, input_shape=input_shape)

# create model
model = Sequential()

# add lower layers of VGG16 to our model, and mark as not trainable
for layer in source_model.layers[:-6]:
    layer.trainable = False
    model.add(layer)

# add extra layers at top of lower layers of pre-trained model
model.add(BatchNorm())
model.add(Flatten())
model.add(Dense(512, activation='relu'))
model.add(BatchNorm())
model.add(Dropout(0.35))
model.add(Dense(512, activation='relu'))
model.add(BatchNorm())
model.add(Dropout(0.35))
model.add(Dense(num_classes, activation='softmax'))

# compile the model
model.compile(loss='categorical_crossentropy', optimizer=keras.optimizers.RMSprop(), metrics=['accuracy'])
print(model.summary())

# using ImageDataGenerator to load and scale data
train_datagen = ImageDataGenerator(rescale=1.0/255, validation_split=0.15)

train_generator = train_datagen.flow_from_directory(
    train_data_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    color_mode="rgb",
    class_mode='categorical',
    subset='training',
    shuffle=True,
    seed=13)

validation_generator = train_datagen.flow_from_directory(
    train_data_dir,
    target_size=(img_width, img_height),
    batch_size=nb_validation_samples,
    color_mode="rgb",
    subset='validation',
    shuffle=False,
    class_mode='categorical')

# define callback for custom learning rate
callback = tf.keras.callbacks.LearningRateScheduler(learning_rate1)

history1 = model.fit(
    train_generator,
    steps_per_epoch=nb_train_samples // batch_size,
    epochs=epochs1,
    callbacks=[callback],
    validation_data=validation_generator,
    validation_steps=1)


# fine tuning the model by unfreezing the lower layers (used from VGG16)
for layer in model.layers[:12]:
    layer.trainable = True

# reset the image generators
train_generator.reset()
validation_generator.reset()

# recompile the model
model.compile(loss='categorical_crossentropy', optimizer=keras.optimizers.RMSprop(), metrics=['accuracy'])
print(model.summary())

# define callback for custom learning rate
callback = tf.keras.callbacks.LearningRateScheduler(learning_rate2)

# history2 = model.fit(
#     train_generator,
#     steps_per_epoch=nb_train_samples // batch_size,
#     epochs=epochs2,
#     callbacks=[callback],
#     validation_data=validation_generator,
#     validation_steps=1)

# # save model
# # model.save_weights('HCR-Net.h5')

# # plot the convergence, in terms of accuracy and loss, of HCR-Net
# plt.plot(history1.history['accuracy']+history2.history['accuracy'])
# plt.plot(history1.history['val_accuracy']+history2.history['val_accuracy'])
# # plt.title('model accuracy')
# plt.ylabel('Accuracy')
# plt.xlabel('Epochs')
# plt.legend(['Train', 'Test'], loc='lower right')
# plt.show()

# plt.plot(history1.history['loss']+history2.history['loss'])
# plt.plot(history1.history['val_loss']+history2.history['val_loss'])
# # plt.title('model loss')
# plt.ylabel('Loss')
# plt.xlabel('Epochs')
# plt.legend(['Train', 'Test'], loc='upper right')
# plt.show()

# # evaluate model and plot confusion matrix
# # filenames = validation_generator.filenames
# predict = model.predict(validation_generator)
# y_pred = np.argmax(predict,axis=-1)
# cf_matrix = confusion_matrix(validation_generator.classes,y_pred)

# # calculate size of confusion matrix figure, and plot it
# fig, ax = plt.subplots(figsize=(math.ceil(num_classes/3.0), math.ceil(num_classes/3.0)))
# labels = list(validation_generator.class_indices.keys())
# sns.heatmap(cf_matrix, annot=True, xticklabels=labels, yticklabels=labels, fmt='', cmap='Blues')
# Out:
# 2023-01-12 21:46:35.805453: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  block1_conv1 (Conv2D)       (None, 32, 32, 64)        1792
#
#  block1_conv2 (Conv2D)       (None, 32, 32, 64)        36928
#
#  block1_pool (MaxPooling2D)  (None, 16, 16, 64)        0
#
#  block2_conv1 (Conv2D)       (None, 16, 16, 128)       73856
#
#  block2_conv2 (Conv2D)       (None, 16, 16, 128)       147584
#
#  block2_pool (MaxPooling2D)  (None, 8, 8, 128)         0
#
#  block3_conv1 (Conv2D)       (None, 8, 8, 256)         295168
#
#  block3_conv2 (Conv2D)       (None, 8, 8, 256)         590080
#
#  block3_conv3 (Conv2D)       (None, 8, 8, 256)         590080
#
#  block3_pool (MaxPooling2D)  (None, 4, 4, 256)         0
#
#  block4_conv1 (Conv2D)       (None, 4, 4, 512)         1180160
#
#  block4_conv2 (Conv2D)       (None, 4, 4, 512)         2359808
#
#  batch_normalization (BatchN  (None, 4, 4, 512)        2048
#  ormalization)
#
#  flatten (Flatten)           (None, 8192)              0
#
#  dense (Dense)               (None, 512)               4194816
#
#  batch_normalization_1 (Batc  (None, 512)              2048
#  hNormalization)
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense_1 (Dense)             (None, 512)               262656
#
#  batch_normalization_2 (Batc  (None, 512)              2048
#  hNormalization)
#
#  dropout_1 (Dropout)         (None, 512)               0
#
#  dense_2 (Dense)             (None, 15)                7695
#
# =================================================================
# Total params: 9,746,767
# Trainable params: 4,468,239
# Non-trainable params: 5,278,528
# _________________________________________________________________
# None
# Found 6375 images belonging to 15 classes.
# Found 1125 images belonging to 15 classes.
# Epoch 1/30
# 199/199 [==============================] - 50s 245ms/step - loss: 0.7350 - accuracy: 0.7653 - val_loss: 0.9608 - val_accuracy: 0.6800 - lr: 1.0000e-04
# Epoch 2/30
# 199/199 [==============================] - 43s 214ms/step - loss: 0.3136 - accuracy: 0.8906 - val_loss: 0.9941 - val_accuracy: 0.6827 - lr: 1.0000e-04
# Epoch 3/30
#  46/199 [=====>........................] - ETA: 30s - loss: 0.2600 - accuracy: 0.9035

# %%
##############################################################################
import logging
logging.getLogger("tensorflow").disabled = True
import numpy as np
import math
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import f1_score, precision_score, recall_score, accuracy_score

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dropout, Flatten, Dense
from tensorflow.keras.layers import BatchNormalization as BatchNorm

# pre-trained models
from keras.applications.vgg16 import VGG16

# custom learning rates
import learning_rate as lr

# %matplotlib inline

##############################################################################
# please change following for your dataset (dataset details and learning params)
# dataset details
train_data_dir =  '/home/engs2426/Dropbox/AC/Train/'
validation_data_dir =  '/home/engs2426/Dropbox/AC/Test/'
# train_data_dir =  '/Users/vinodkumar/Downloads/archive/AC/Train/'
# validation_data_dir =  '/Users/vinodkumar/Downloads/archive/AC/Test/'

nb_train_samples = 13440
nb_validation_samples = 3360
num_classes = 28

# learning params
epochs1 = 30
epochs2 = 20
learning_rate1 = lr.decayed_learning_rate
learning_rate2 = lr.decayed_learning_rate_tuned20

# set seeds for reproduceability
np.random.seed(1)
tf.random.set_seed(1)
##############################################################################
batch_size = 32
# dimensions of our images.
img_width, img_height = 32, 32
input_shape = (img_width, img_height, 3)
##############################################################################
#### TRAINING PHASE - I #########
#################################
# using VGG16: load model without classifier layer, and using weights from ImageNet
source_model = VGG16(include_top=False, input_shape=input_shape)

# create a new model using lower layers of VGG16 upto block4_conv2,
# and mark as not trainable, i.e., freeze the lower layers
model = Sequential()
for layer in source_model.layers[:-6]:
    layer.trainable = False
    model.add(layer)

# add extra layers at top of lower layers of pre-trained VGG16
model.add(BatchNorm())
model.add(Flatten())
model.add(Dense(512, activation='relu'))
model.add(BatchNorm())
model.add(Dropout(0.35))
model.add(Dense(512, activation='relu'))
model.add(BatchNorm())
model.add(Dropout(0.35))
model.add(Dense(num_classes, activation='softmax'))

model.compile(loss='categorical_crossentropy', optimizer=keras.optimizers.RMSprop(), metrics=['accuracy'])
print(model.summary())

# using ImageDataGenerator to load and scale data
train_datagen = ImageDataGenerator(rescale=1.0/255)
test_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
                    train_data_dir,
                    target_size=(img_width, img_height),
                    batch_size=batch_size,
                    color_mode="rgb",
                    class_mode='categorical',
                    shuffle=True,
                    seed=13)
validation_generator = test_datagen.flow_from_directory(
                    validation_data_dir,
                    target_size=(img_width, img_height),
                    batch_size=nb_validation_samples,
                    color_mode="rgb",
                    shuffle=False,
                    class_mode='categorical')

# define callback for custom learning rate
callback = tf.keras.callbacks.LearningRateScheduler(learning_rate1)

history1 = model.fit(
                train_generator,
                steps_per_epoch=nb_train_samples // batch_size,
                epochs=epochs1,
                callbacks=[callback],
                validation_data=validation_generator,
                validation_steps=1)

# save the model
model.save_weights('./results/HCR-Net-I.h5')

#################################
#### TRAINING PHASE - II #########
#################################
# fine tuning the model by unfreezing the lower layers (used from VGG16)
for layer in model.layers[:12]:
    layer.trainable = True

# reset the image generators
train_generator.reset()
validation_generator.reset()

# recompile the model
model.compile(loss='categorical_crossentropy', optimizer=keras.optimizers.RMSprop(), metrics=['accuracy'])
print(model.summary())

# define callback for custom learning rate
callback = tf.keras.callbacks.LearningRateScheduler(learning_rate2)

history2 = model.fit(
                train_generator,
                steps_per_epoch=nb_train_samples // batch_size,
                epochs=epochs2,
                callbacks=[callback],
                validation_data=validation_generator,
                validation_steps=1)

# save the model
model.save_weights('./results/HCR-Net-II.h5')

##############################################################################
# plot the convergence, in terms of accuracy and loss
plt.plot(history1.history['accuracy']+history2.history['accuracy'])
plt.plot(history1.history['val_accuracy']+history2.history['val_accuracy'])
# plt.title('model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['Train', 'Test'], loc='lower right')
plt.show()

plt.plot(history1.history['loss']+history2.history['loss'])
plt.plot(history1.history['val_loss']+history2.history['val_loss'])
# plt.title('model loss')
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.legend(['Train', 'Test'], loc='upper right')
plt.show()

# evaluate model and plot confusion matrix
# filenames = validation_generator.filenames
predict = model.predict(validation_generator)
y_pred = np.argmax(predict,axis=-1)
cf_matrix = confusion_matrix(validation_generator.classes,y_pred)

# calculate size of confusion matrix figure, and plot it
fig, ax = plt.subplots(figsize=(math.ceil(num_classes/3.0), math.ceil(num_classes/3.0)))
labels = list(validation_generator.class_indices.keys())
sns.heatmap(cf_matrix, annot=True, xticklabels=labels, yticklabels=labels, fmt='', cmap='Blues')
plt.ylabel('Actual Class')
plt.xlabel('Predicted Class')
# Non-trainable params: 3,072
# _________________________________________________________________
# None
# Epoch 1/20
# 420/420 [==============================] - 101s 237ms/step - loss: 0.0645 - accuracy: 0.9788 - val_loss: 0.2275 - val_accuracy: 0.9429 - lr: 1.0000e-07
# Epoch 2/20
# 420/420 [==============================] - 96s 229ms/step - loss: 0.0584 - accuracy: 0.9815 - val_loss: 0.2289 - val_accuracy: 0.9426 - lr: 1.0000e-07
# Epoch 3/20
# 420/420 [==============================] - 97s 230ms/step - loss: 0.0575 - accuracy: 0.9817 - val_loss: 0.2232 - val_accuracy: 0.9432 - lr: 1.0000e-07
# Epoch 4/20
# 420/420 [==============================] - 100s 237ms/step - loss: 0.0557 - accuracy: 0.9814 - val_loss: 0.2216 - val_accuracy: 0.9438 - lr: 1.0000e-07
# Epoch 5/20
# 420/420 [==============================] - 99s 235ms/step - loss: 0.0550 - accuracy: 0.9828 - val_loss: 0.2195 - val_accuracy: 0.9446 - lr: 1.0000e-07
# Epoch 6/20
# 420/420 [==============================] - 101s 240ms/step - loss: 0.0617 - accuracy: 0.9799 - val_loss: 0.2291 - val_accuracy: 0.9381 - lr: 5.0000e-06
# Epoch 7/20
# 420/420 [==============================] - 98s 233ms/step - loss: 0.0539 - accuracy: 0.9821 - val_loss: 0.2319 - val_accuracy: 0.9411 - lr: 5.0000e-06
# Epoch 8/20
# 420/420 [==============================] - 99s 237ms/step - loss: 0.0509 - accuracy: 0.9838 - val_loss: 0.2257 - val_accuracy: 0.9432 - lr: 5.0000e-06
# Epoch 9/20
# 420/420 [==============================] - 96s 228ms/step - loss: 0.0470 - accuracy: 0.9851 - val_loss: 0.2245 - val_accuracy: 0.9423 - lr: 5.0000e-06
# Epoch 10/20
# 332/420 [======================>.......] - ETA: 19s - loss: 0.0413 - accuracy: 0.9879

# %%
##############################################################################
import logging
logging.getLogger("tensorflow").disabled = True
import numpy as np
import math
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import f1_score, precision_score, recall_score, accuracy_score

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dropout, Flatten, Dense
from tensorflow.keras.layers import BatchNormalization as BatchNorm

# pre-trained models
from keras.applications.vgg16 import VGG16

# custom learning rates
import learning_rate as lr

# %matplotlib inline

##############################################################################
# please change following for your dataset (dataset details and learning params)
# dataset details
train_data_dir =  '/home/engs2426/Dropbox/AC/Train/'
validation_data_dir =  '/home/engs2426/Dropbox/AC/Test/'
# train_data_dir =  '/Users/vinodkumar/Downloads/archive/AC/Train/'
# validation_data_dir =  '/Users/vinodkumar/Downloads/archive/AC/Test/'
nb_train_samples = 13440
nb_validation_samples = 3360
num_classes = 28

# learning params
epochs1 = 10
epochs2 = 50
learning_rate1 = lr.decayed_learning_rate
learning_rate2 = lr.decayed_learning_rate_tuned50

# set seeds for reproduceability
np.random.seed(1)
tf.random.set_seed(1)
##############################################################################
batch_size = 32
# dimensions of our images.
img_width, img_height = 32, 32
input_shape = (img_width, img_height, 3)
##############################################################################
#### TRAINING PHASE - I #########
#################################
# using VGG16: load model without classifier layer, and using weights from ImageNet
source_model = VGG16(include_top=False, input_shape=input_shape)

# create a new model using lower layers of VGG16 upto block4_conv2,
# and mark as not trainable, i.e., freeze the lower layers
model = Sequential()
for layer in source_model.layers[:-6]:
    layer.trainable = False
    model.add(layer)

# add extra layers at top of lower layers of pre-trained VGG16
model.add(BatchNorm())
model.add(Flatten())
model.add(Dense(512, activation='relu'))
model.add(BatchNorm())
model.add(Dropout(0.35))
model.add(Dense(512, activation='relu'))
model.add(BatchNorm())
model.add(Dropout(0.35))
model.add(Dense(num_classes, activation='softmax'))

model.compile(loss='categorical_crossentropy', optimizer=keras.optimizers.RMSprop(), metrics=['accuracy'])
print(model.summary())

# using ImageDataGenerator to load, augment and scale data
train_datagen = ImageDataGenerator(
                    rescale=1.0/255,
                    rotation_range=10,
                    width_shift_range=0.05,
                    height_shift_range=0.05,
                    shear_range=0.1,
                    zoom_range=0.05,
                    fill_mode='constant',
                    cval = 0
                )
test_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
                    train_data_dir,
                    target_size=(img_width, img_height),
                    batch_size=batch_size,
                    color_mode="rgb",
                    class_mode='categorical',
                    shuffle=True,
                    seed=13)
validation_generator = test_datagen.flow_from_directory(
                    validation_data_dir,
                    target_size=(img_width, img_height),
                    batch_size=nb_validation_samples,
                    color_mode="rgb",
                    shuffle=False,
                    class_mode='categorical')

# define callback for custom learning rate
callback = tf.keras.callbacks.LearningRateScheduler(learning_rate1)

history1 = model.fit(
                train_generator,
                steps_per_epoch=nb_train_samples // batch_size,
                epochs=epochs1,
                callbacks=[callback],
                validation_data=validation_generator,
                validation_steps=1)

# save the model
model.save_weights('./results/HCR-Net-Aug-I.h5')

#################################
#### TRAINING PHASE - II #########
#################################
# fine tuning the model by unfreezing the lower layers (used from VGG16)
for layer in model.layers[:12]:
    layer.trainable = True

# reset the image generators
train_generator.reset()
validation_generator.reset()

# recompile the model
model.compile(loss='categorical_crossentropy', optimizer=keras.optimizers.RMSprop(), metrics=['accuracy'])
print(model.summary())

# define callback for custom learning rate
callback = tf.keras.callbacks.LearningRateScheduler(learning_rate2)

history2 = model.fit(
                train_generator,
                steps_per_epoch=nb_train_samples // batch_size,
                epochs=epochs2,
                callbacks=[callback],
                validation_data=validation_generator,
                validation_steps=1)

# save the model
model.save_weights('./results/HCR-Net-Aug-II.h5')

##############################################################################
# plot the convergence, in terms of accuracy and loss
plt.plot(history1.history['accuracy']+history2.history['accuracy'])
plt.plot(history1.history['val_accuracy']+history2.history['val_accuracy'])
# plt.title('model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['Train', 'Test'], loc='lower right')
plt.show()

plt.plot(history1.history['loss']+history2.history['loss'])
plt.plot(history1.history['val_loss']+history2.history['val_loss'])
# plt.title('model loss')
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.legend(['Train', 'Test'], loc='upper right')
plt.show()

# evaluate model and plot confusion matrix
# filenames = validation_generator.filenames
predict = model.predict(validation_generator)
y_pred = np.argmax(predict,axis=-1)
cf_matrix = confusion_matrix(validation_generator.classes,y_pred)

# calculate size of confusion matrix figure, and plot it
fig, ax = plt.subplots(figsize=(math.ceil(num_classes/3.0), math.ceil(num_classes/3.0)))
labels = list(validation_generator.class_indices.keys())
sns.heatmap(cf_matrix, annot=True, xticklabels=labels, yticklabels=labels, fmt='', cmap='Blues')
plt.ylabel('Actual Class')
plt.xlabel('Predicted Class')
##############################################################################
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  block1_conv1 (Conv2D)       (None, 32, 32, 64)        1792
#
#  block1_conv2 (Conv2D)       (None, 32, 32, 64)        36928
#
#  block1_pool (MaxPooling2D)  (None, 16, 16, 64)        0
#
#  block2_conv1 (Conv2D)       (None, 16, 16, 128)       73856
#
#  block2_conv2 (Conv2D)       (None, 16, 16, 128)       147584
#
#  block2_pool (MaxPooling2D)  (None, 8, 8, 128)         0
#
#  block3_conv1 (Conv2D)       (None, 8, 8, 256)         295168
#
#  block3_conv2 (Conv2D)       (None, 8, 8, 256)         590080
#
#  block3_conv3 (Conv2D)       (None, 8, 8, 256)         590080
#
#  block3_pool (MaxPooling2D)  (None, 4, 4, 256)         0
#
#  block4_conv1 (Conv2D)       (None, 4, 4, 512)         1180160
#
#  block4_conv2 (Conv2D)       (None, 4, 4, 512)         2359808
#
#  batch_normalization_3 (Batc  (None, 4, 4, 512)        2048
#  hNormalization)
#
#  flatten_1 (Flatten)         (None, 8192)              0
#
#  dense_3 (Dense)             (None, 512)               4194816
#
#  batch_normalization_4 (Batc  (None, 512)              2048
#  hNormalization)
#
#  dropout_2 (Dropout)         (None, 512)               0
#
#  dense_4 (Dense)             (None, 512)               262656
#
#  batch_normalization_5 (Batc  (None, 512)              2048
#  hNormalization)
#
#  dropout_3 (Dropout)         (None, 512)               0
#
#  dense_5 (Dense)             (None, 28)                14364
#
# =================================================================
# Total params: 9,753,436
# Trainable params: 4,474,908
# Non-trainable params: 5,278,528
# _________________________________________________________________
# None
# Found 13440 images belonging to 28 classes.
# Found 3360 images belonging to 28 classes.
# Epoch 1/10
# 420/420 [==============================] - 35s 80ms/step - loss: 1.2673 - accuracy: 0.6219 - val_loss: 0.4810 - val_accuracy: 0.8452 - lr: 1.0000e-04
# Epoch 2/10
# 420/420 [==============================] - 31s 75ms/step - loss: 0.6623 - accuracy: 0.7880 - val_loss: 0.4001 - val_accuracy: 0.8774 - lr: 1.0000e-04
# Epoch 3/10
# 420/420 [==============================] - 32s 76ms/step - loss: 0.5264 - accuracy: 0.8354 - val_loss: 0.3583 - val_accuracy: 0.8848 - lr: 1.0000e-04
# Epoch 4/10
# 420/420 [==============================] - 32s 76ms/step - loss: 0.4457 - accuracy: 0.8561 - val_loss: 0.3577 - val_accuracy: 0.8818 - lr: 1.0000e-04
# Epoch 5/10
# 420/420 [==============================] - 31s 75ms/step - loss: 0.3997 - accuracy: 0.8704 - val_loss: 0.3131 - val_accuracy: 0.9033 - lr: 1.0000e-04
# Epoch 6/10
# 420/420 [==============================] - 30s 73ms/step - loss: 0.3334 - accuracy: 0.8908 - val_loss: 0.2946 - val_accuracy: 0.9048 - lr: 5.0000e-05
# Epoch 7/10
# 420/420 [==============================] - 31s 74ms/step - loss: 0.3151 - accuracy: 0.8939 - val_loss: 0.2861 - val_accuracy: 0.9101 - lr: 5.0000e-05
# Epoch 8/10
# 420/420 [==============================] - 32s 75ms/step - loss: 0.2848 - accuracy: 0.9033 - val_loss: 0.2620 - val_accuracy: 0.9185 - lr: 5.0000e-05
# Epoch 9/10
# 420/420 [==============================] - 31s 75ms/step - loss: 0.2857 - accuracy: 0.9064 - val_loss: 0.2661 - val_accuracy: 0.9128 - lr: 5.0000e-05
# Epoch 10/10
# 420/420 [==============================] - 31s 74ms/step - loss: 0.2698 - accuracy: 0.9150 - val_loss: 0.2602 - val_accuracy: 0.9164 - lr: 5.0000e-05
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  block1_conv1 (Conv2D)       (None, 32, 32, 64)        1792
#
#  block1_conv2 (Conv2D)       (None, 32, 32, 64)        36928
#
#  block1_pool (MaxPooling2D)  (None, 16, 16, 64)        0
#
#  block2_conv1 (Conv2D)       (None, 16, 16, 128)       73856
#
#  block2_conv2 (Conv2D)       (None, 16, 16, 128)       147584
#
#  block2_pool (MaxPooling2D)  (None, 8, 8, 128)         0
#
#  block3_conv1 (Conv2D)       (None, 8, 8, 256)         295168
#
#  block3_conv2 (Conv2D)       (None, 8, 8, 256)         590080
#
#  block3_conv3 (Conv2D)       (None, 8, 8, 256)         590080
#
#  block3_pool (MaxPooling2D)  (None, 4, 4, 256)         0
#
#  block4_conv1 (Conv2D)       (None, 4, 4, 512)         1180160
#
#  block4_conv2 (Conv2D)       (None, 4, 4, 512)         2359808
#
#  batch_normalization_3 (Batc  (None, 4, 4, 512)        2048
#  hNormalization)
#
#  flatten_1 (Flatten)         (None, 8192)              0
#
#  dense_3 (Dense)             (None, 512)               4194816
#
#  batch_normalization_4 (Batc  (None, 512)              2048
#  hNormalization)
#
#  dropout_2 (Dropout)         (None, 512)               0
#
#  dense_4 (Dense)             (None, 512)               262656
#
#  batch_normalization_5 (Batc  (None, 512)              2048
#  hNormalization)
#
#  dropout_3 (Dropout)         (None, 512)               0
#
#  dense_5 (Dense)             (None, 28)                14364
#
# =================================================================
# Total params: 9,753,436
# Trainable params: 9,750,364
# Non-trainable params: 3,072
# _________________________________________________________________
# None
# Epoch 1/50
# 420/420 [==============================] - 101s 236ms/step - loss: 0.2469 - accuracy: 0.9187 - val_loss: 0.2514 - val_accuracy: 0.9220 - lr: 1.0000e-07
# Epoch 2/50
# 420/420 [==============================] - 101s 240ms/step - loss: 0.2392 - accuracy: 0.9187 - val_loss: 0.2502 - val_accuracy: 0.9220 - lr: 1.0000e-07
# Epoch 3/50
# 420/420 [==============================] - 98s 233ms/step - loss: 0.2307 - accuracy: 0.9208 - val_loss: 0.2480 - val_accuracy: 0.9232 - lr: 1.0000e-07
# Epoch 4/50
# 420/420 [==============================] - 99s 235ms/step - loss: 0.2371 - accuracy: 0.9240 - val_loss: 0.2456 - val_accuracy: 0.9232 - lr: 1.0000e-07
# Epoch 5/50
# 420/420 [==============================] - 98s 232ms/step - loss: 0.2406 - accuracy: 0.9228 - val_loss: 0.2458 - val_accuracy: 0.9235 - lr: 1.0000e-07
# Epoch 6/50
# 420/420 [==============================] - 96s 227ms/step - loss: 0.2420 - accuracy: 0.9208 - val_loss: 0.2476 - val_accuracy: 0.9211 - lr: 5.0000e-06
# Epoch 7/50
# 420/420 [==============================] - 99s 235ms/step - loss: 0.2152 - accuracy: 0.9300 - val_loss: 0.2287 - val_accuracy: 0.9274 - lr: 5.0000e-06
# Epoch 8/50
# 420/420 [==============================] - ETA: 0s - loss: 0.2153 - accuracy: 0.9274
