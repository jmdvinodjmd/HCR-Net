# %%
# with fine tuning
import os
import numpy as np
import matplotlib.pyplot as plt
import glob

# %matplotlib inline

# example of horizontal shift image augmentation
from numpy import expand_dims
from tensorflow import keras
from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array
from keras.preprocessing.image import ImageDataGenerator
from matplotlib import pyplot

from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D
from keras.layers import Activation, Dropout, Flatten, Dense
from keras import backend as K
from keras.models import Model

from keras.optimizers import RMSprop
from keras.optimizers import Adam

# pre-trained models
from tensorflow.keras.applications.vgg19 import VGG19
from keras.applications.vgg16 import VGG16
from keras.applications.inception_v3 import InceptionV3

from keras.layers import BatchNormalization as BatchNorm
import tensorflow as tf
import math

from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import plot_confusion_matrix
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import f1_score, precision_score, recall_score, accuracy_score

from learning_rate import decayed_learning_rate, decayed_learning_rate_tuned

np.random.seed(1)
tf.random.set_seed(1)

# dataset details
train_data_dir =      './Data/Online/online_pendigits/offline/train/'
validation_data_dir = './Data/Online/online_pendigits/offline/test/'
nb_train_samples = 7494
nb_validation_samples = 3498
num_classes = 10

epochs = 30
batch_size = 16
# dimensions of our images.
img_width, img_height = 32, 32
input_shape = (img_width, img_height, 3)

# using VGG16
# load model without classifier layers
model = Sequential()
# # create the VGG16 model with only the convolutional layers, and using weights from ImageNet
source_model = VGG16(include_top=False, input_shape=input_shape)

# mark loaded layers as not trainable
for layer in source_model.layers[:-6]:
    layer.trainable = False
    model.add(layer)

model.add(BatchNorm())
model.add(Flatten())
model.add(Dense(512, activation='relu'))
model.add(BatchNorm())
model.add(Dropout(0.35))
model.add(Dense(512, activation='relu'))
model.add(BatchNorm())
model.add(Dropout(0.35))
model.add(Dense(num_classes, activation='softmax'))

model.compile(loss='categorical_crossentropy', optimizer=keras.optimizers.RMSprop(), metrics=['accuracy'])
print(model.summary())

# this is the augmentation configuration we will use for training
train_datagen = ImageDataGenerator(
                    rescale=1.0/255,
                    rotation_range=5,
                    width_shift_range=0.05,
                    height_shift_range=0.05,
                    shear_range=0.5,
                    zoom_range=0.05,
            #         horizontal_flip=True,
                    fill_mode='constant',
                    cval = 0
                )

# this is the augmentation configuration we will use for testing:
# only rescaling for test dataset
test_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
    train_data_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    color_mode="rgb",
    class_mode='categorical',
#     subset='training',
    shuffle=True,
    seed=13)

validation_generator = test_datagen.flow_from_directory(
    validation_data_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    color_mode="rgb",
#     subset='validation',
    shuffle=False,
    class_mode='categorical')

# custom learning rate
callback = tf.keras.callbacks.LearningRateScheduler(decayed_learning_rate)

history1 = model.fit(
    train_generator,
    steps_per_epoch=nb_train_samples // batch_size,
    epochs=epochs,
    callbacks=[callback],
    validation_data=validation_generator,
    validation_steps=nb_validation_samples // batch_size)


# fine tuning the model
epochs = 20

# mark layers as trainable
for layer in model.layers[:12]:
    layer.trainable = True

train_generator.reset()
validation_generator.reset()

model.compile(loss='categorical_crossentropy', optimizer=keras.optimizers.RMSprop(), metrics=['accuracy'])
print(model.summary())

# custom learning rate
callback = tf.keras.callbacks.LearningRateScheduler(decayed_learning_rate_tuned)

history2 = model.fit(
    train_generator,
    steps_per_epoch=nb_train_samples // batch_size,
    epochs=epochs,
    callbacks=[callback],
    validation_data=validation_generator,
    validation_steps=nb_validation_samples // batch_size)

# model.save_weights('first_try0.h5')

# summarize history for accuracy
plt.plot(history1.history['accuracy']+history2.history['accuracy'])
plt.plot(history1.history['val_accuracy']+history2.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epochs')
plt.legend(['train', 'test'], loc='upper right')
plt.show()
# summarize history for loss
plt.plot(history1.history['loss']+history2.history['loss'])
plt.plot(history1.history['val_loss']+history2.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epochs')
plt.legend(['train', 'test'], loc='upper right')
plt.show()

filenames = validation_generator.filenames

predict = model.predict(validation_generator)
y_pred = np.argmax(predict,axis=-1)

cm = confusion_matrix(validation_generator.classes,y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
# disp = ConfusionMatrixDisplay(confusion_matrix=cm,
#                               display_labels=clf.classes_)

fig, ax = plt.subplots(figsize=(math.ceil(num_classes/3.0), math.ceil(num_classes/3.0)))
disp.plot(ax=ax, cmap=plt.cm.Blues)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# block1_conv1 (Conv2D)        (None, 32, 32, 64)        1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 32, 32, 64)        36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 16, 16, 64)        0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 16, 16, 128)       73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 16, 16, 128)       147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 8, 8, 128)         0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 8, 8, 256)         295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 8, 8, 256)         590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 8, 8, 256)         590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 4, 4, 256)         0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 4, 4, 512)         1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 4, 4, 512)         2359808
# _________________________________________________________________
# batch_normalization (BatchNo (None, 4, 4, 512)         2048
# _________________________________________________________________
# flatten (Flatten)            (None, 8192)              0
# _________________________________________________________________
# dense (Dense)                (None, 512)               4194816
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 512)               2048
# _________________________________________________________________
# dropout (Dropout)            (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               262656
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 512)               2048
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                5130
# =================================================================
# Total params: 9,744,202
# Trainable params: 4,465,674
# Non-trainable params: 5,278,528
# _________________________________________________________________
# None
# Found 7494 images belonging to 10 classes.
# Found 3498 images belonging to 10 classes.
# Epoch 1/30
# 468/468 [==============================] - 228s 487ms/step - loss: 3.2653 - accuracy: 0.0943 - val_loss: 2.6884 - val_accuracy: 0.0975 - lr: 5.0000e-05
# Epoch 2/30
# 468/468 [==============================] - 269s 575ms/step - loss: 3.0403 - accuracy: 0.1081 - val_loss: 2.6266 - val_accuracy: 0.1061 - lr: 5.0000e-05
# Epoch 3/30
# 468/468 [==============================] - 274s 585ms/step - loss: 2.9684 - accuracy: 0.1099 - val_loss: 2.5921 - val_accuracy: 0.0975 - lr: 5.0000e-05
# Epoch 4/30
# 468/468 [==============================] - 276s 590ms/step - loss: 2.8754 - accuracy: 0.1141 - val_loss: 2.5789 - val_accuracy: 0.1015 - lr: 5.0000e-05
# Epoch 5/30
# 468/468 [==============================] - 282s 602ms/step - loss: 2.8456 - accuracy: 0.1114 - val_loss: 2.5550 - val_accuracy: 0.0963 - lr: 5.0000e-05
# Epoch 6/30
# 468/468 [==============================] - 276s 589ms/step - loss: 2.8049 - accuracy: 0.1175 - val_loss: 2.5356 - val_accuracy: 0.1069 - lr: 5.0000e-05
# Epoch 7/30
# 468/468 [==============================] - 278s 594ms/step - loss: 2.7413 - accuracy: 0.1298 - val_loss: 2.5034 - val_accuracy: 0.0952 - lr: 5.0000e-05
# Epoch 8/30
# 468/468 [==============================] - 255s 545ms/step - loss: 2.7456 - accuracy: 0.1187 - val_loss: 2.4954 - val_accuracy: 0.0912 - lr: 5.0000e-05
# Epoch 9/30
# 468/468 [==============================] - 269s 574ms/step - loss: 2.6888 - accuracy: 0.1257 - val_loss: 2.4795 - val_accuracy: 0.0983 - lr: 5.0000e-05
# Epoch 10/30
# 468/468 [==============================] - 252s 539ms/step - loss: 2.6972 - accuracy: 0.1229 - val_loss: 2.4729 - val_accuracy: 0.0995 - lr: 5.0000e-05
# Epoch 11/30
# 468/468 [==============================] - 244s 522ms/step - loss: 2.6358 - accuracy: 0.1359 - val_loss: 2.4484 - val_accuracy: 0.1046 - lr: 1.0000e-05
# Epoch 12/30
# 468/468 [==============================] - 272s 581ms/step - loss: 2.6187 - accuracy: 0.1353 - val_loss: 2.4505 - val_accuracy: 0.1001 - lr: 1.0000e-05
# Epoch 13/30
# 468/468 [==============================] - 281s 600ms/step - loss: 2.6106 - accuracy: 0.1336 - val_loss: 2.4481 - val_accuracy: 0.1003 - lr: 1.0000e-05
# Epoch 14/30
# 468/468 [==============================] - 273s 582ms/step - loss: 2.6093 - accuracy: 0.1379 - val_loss: 2.4562 - val_accuracy: 0.1001 - lr: 1.0000e-05
# Epoch 15/30
# 468/468 [==============================] - 270s 577ms/step - loss: 2.5902 - accuracy: 0.1368 - val_loss: 2.4514 - val_accuracy: 0.0989 - lr: 1.0000e-05
# Epoch 16/30
# 468/468 [==============================] - 265s 567ms/step - loss: 2.5966 - accuracy: 0.1300 - val_loss: 2.4525 - val_accuracy: 0.1032 - lr: 1.0000e-05
# Epoch 17/30
# 468/468 [==============================] - 257s 549ms/step - loss: 2.6042 - accuracy: 0.1313 - val_loss: 2.4579 - val_accuracy: 0.1009 - lr: 8.0000e-06
# Epoch 18/30
# 468/468 [==============================] - 277s 592ms/step - loss: 2.5561 - accuracy: 0.1391 - val_loss: 2.4490 - val_accuracy: 0.1046 - lr: 8.0000e-06
# Epoch 19/30
# 468/468 [==============================] - 258s 551ms/step - loss: 2.5858 - accuracy: 0.1348 - val_loss: 2.4568 - val_accuracy: 0.1024 - lr: 8.0000e-06
# Epoch 20/30
# 468/468 [==============================] - 241s 514ms/step - loss: 2.5828 - accuracy: 0.1348 - val_loss: 2.4578 - val_accuracy: 0.1009 - lr: 8.0000e-06
# Epoch 21/30
# 468/468 [==============================] - 254s 543ms/step - loss: 2.5571 - accuracy: 0.1459 - val_loss: 2.4506 - val_accuracy: 0.1003 - lr: 8.0000e-06
# Epoch 22/30
# 468/468 [==============================] - 271s 580ms/step - loss: 2.5662 - accuracy: 0.1396 - val_loss: 2.4497 - val_accuracy: 0.0992 - lr: 8.0000e-06
# Epoch 23/30
# 468/468 [==============================] - 267s 571ms/step - loss: 2.5560 - accuracy: 0.1405 - val_loss: 2.4525 - val_accuracy: 0.1021 - lr: 8.0000e-06
# Epoch 24/30
# 468/468 [==============================] - 283s 605ms/step - loss: 2.5558 - accuracy: 0.1381 - val_loss: 2.4507 - val_accuracy: 0.1009 - lr: 8.0000e-06
# Epoch 25/30
# 468/468 [==============================] - 285s 609ms/step - loss: 2.5515 - accuracy: 0.1363 - val_loss: 2.4517 - val_accuracy: 0.1035 - lr: 8.0000e-06
# Epoch 26/30
# 468/468 [==============================] - 293s 627ms/step - loss: 2.5472 - accuracy: 0.1397 - val_loss: 2.4448 - val_accuracy: 0.1018 - lr: 8.0000e-06
# Epoch 27/30
# 468/468 [==============================] - 274s 586ms/step - loss: 2.5307 - accuracy: 0.1372 - val_loss: 2.4545 - val_accuracy: 0.1032 - lr: 8.0000e-06
# Epoch 28/30
# 468/468 [==============================] - 273s 584ms/step - loss: 2.5490 - accuracy: 0.1430 - val_loss: 2.4578 - val_accuracy: 0.1049 - lr: 8.0000e-06
# Epoch 29/30
# 468/468 [==============================] - 267s 571ms/step - loss: 2.5248 - accuracy: 0.1458 - val_loss: 2.4561 - val_accuracy: 0.0995 - lr: 8.0000e-06
# Epoch 30/30
# 468/468 [==============================] - 260s 557ms/step - loss: 2.5148 - accuracy: 0.1478 - val_loss: 2.4619 - val_accuracy: 0.1026 - lr: 8.0000e-06
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# block1_conv1 (Conv2D)        (None, 32, 32, 64)        1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 32, 32, 64)        36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 16, 16, 64)        0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 16, 16, 128)       73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 16, 16, 128)       147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 8, 8, 128)         0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 8, 8, 256)         295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 8, 8, 256)         590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 8, 8, 256)         590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 4, 4, 256)         0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 4, 4, 512)         1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 4, 4, 512)         2359808
# _________________________________________________________________
# batch_normalization (BatchNo (None, 4, 4, 512)         2048
# _________________________________________________________________
# flatten (Flatten)            (None, 8192)              0
# _________________________________________________________________
# dense (Dense)                (None, 512)               4194816
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 512)               2048
# _________________________________________________________________
# dropout (Dropout)            (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               262656
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 512)               2048
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                5130
# =================================================================
# Total params: 9,744,202
# Trainable params: 9,741,130
# Non-trainable params: 3,072
# _________________________________________________________________
# None
# Epoch 1/20
# 468/468 [==============================] - 623s 1s/step - loss: 2.5303 - accuracy: 0.1459 - val_loss: 2.4559 - val_accuracy: 0.1046 - lr: 1.0000e-07
# Epoch 2/20
# 468/468 [==============================] - 636s 1s/step - loss: 2.5192 - accuracy: 0.1503 - val_loss: 2.4626 - val_accuracy: 0.1044 - lr: 1.0000e-07
# Epoch 3/20
# 468/468 [==============================] - 673s 1s/step - loss: 2.5116 - accuracy: 0.1468 - val_loss: 2.4622 - val_accuracy: 0.1046 - lr: 1.0000e-07
# Epoch 4/20
# 468/468 [==============================] - 672s 1s/step - loss: 2.5086 - accuracy: 0.1483 - val_loss: 2.4612 - val_accuracy: 0.1029 - lr: 1.0000e-07
# Epoch 5/20
# 468/468 [==============================] - 612s 1s/step - loss: 2.4961 - accuracy: 0.1532 - val_loss: 2.4602 - val_accuracy: 0.1046 - lr: 1.0000e-07
# Epoch 6/20
# 468/468 [==============================] - 514s 1s/step - loss: 2.5287 - accuracy: 0.1371 - val_loss: 2.4832 - val_accuracy: 0.0989 - lr: 5.0000e-06
# Epoch 7/20
# 468/468 [==============================] - 517s 1s/step - loss: 2.5234 - accuracy: 0.1483 - val_loss: 2.4976 - val_accuracy: 0.1021 - lr: 5.0000e-06
# Epoch 8/20
# 468/468 [==============================] - 567s 1s/step - loss: 2.5246 - accuracy: 0.1487 - val_loss: 2.4938 - val_accuracy: 0.0978 - lr: 5.0000e-06
# Epoch 9/20
# 468/468 [==============================] - 578s 1s/step - loss: 2.5183 - accuracy: 0.1459 - val_loss: 2.4834 - val_accuracy: 0.1041 - lr: 5.0000e-06
# Epoch 10/20
# 468/468 [==============================] - 568s 1s/step - loss: 2.4886 - accuracy: 0.1495 - val_loss: 2.4880 - val_accuracy: 0.0989 - lr: 5.0000e-06
# Epoch 11/20
# 468/468 [==============================] - 403s 862ms/step - loss: 2.5082 - accuracy: 0.1495 - val_loss: 2.5348 - val_accuracy: 0.1058 - lr: 5.0000e-06
# Epoch 12/20
# 468/468 [==============================] - 370s 790ms/step - loss: 2.4875 - accuracy: 0.1563 - val_loss: 2.4831 - val_accuracy: 0.1001 - lr: 3.0000e-06
# Epoch 13/20
# 468/468 [==============================] - 377s 805ms/step - loss: 2.5153 - accuracy: 0.1474 - val_loss: 2.5366 - val_accuracy: 0.1041 - lr: 3.0000e-06
# Epoch 14/20
# 468/468 [==============================] - 383s 819ms/step - loss: 2.4964 - accuracy: 0.1527 - val_loss: 2.4882 - val_accuracy: 0.0989 - lr: 3.0000e-06
# Epoch 15/20
# 468/468 [==============================] - 405s 865ms/step - loss: 2.4868 - accuracy: 0.1614 - val_loss: 2.5227 - val_accuracy: 0.0983 - lr: 3.0000e-06
# Epoch 16/20
# 468/468 [==============================] - 401s 856ms/step - loss: 2.4842 - accuracy: 0.1543 - val_loss: 2.5072 - val_accuracy: 0.1012 - lr: 3.0000e-06
# Epoch 17/20
# 468/468 [==============================] - 400s 855ms/step - loss: 2.4862 - accuracy: 0.1543 - val_loss: 2.5106 - val_accuracy: 0.1032 - lr: 2.0000e-06
# Epoch 18/20
# 468/468 [==============================] - 361s 771ms/step - loss: 2.4625 - accuracy: 0.1595 - val_loss: 2.5435 - val_accuracy: 0.1024 - lr: 2.0000e-06
# Epoch 19/20
# 468/468 [==============================] - 313s 668ms/step - loss: 2.4873 - accuracy: 0.1577 - val_loss: 2.5312 - val_accuracy: 0.0995 - lr: 2.0000e-06
# Epoch 20/20
# 468/468 [==============================] - 304s 650ms/step - loss: 2.4639 - accuracy: 0.1653 - val_loss: 2.5029 - val_accuracy: 0.0998 - lr: 2.0000e-06

# %%
print('precision_score: ', precision_score(validation_generator.classes,y_pred, average="macro"))
print('recall_score   : ', recall_score(validation_generator.classes,y_pred, average="macro"))
print('f1_score       : ', f1_score(validation_generator.classes,y_pred, average="macro"))
print('accuracy_score : ', accuracy_score(validation_generator.classes,y_pred, normalize=True))

print("\nBest accuracy  : ", max(max(history1.history['val_accuracy']), max(history2.history['val_accuracy'])))
# Out:
# precision_score:  0.10160622032408237
# recall_score   :  0.09959140902953416
# f1_score       :  0.09654149460437053
# accuracy_score :  0.09977129788450544
#
# Best accuracy  :  0.10693807154893875

# %%
# with fine tuning
import os
import numpy as np
import matplotlib.pyplot as plt
import glob

# %matplotlib inline

# example of horizontal shift image augmentation
from numpy import expand_dims
from tensorflow import keras
from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array
from keras.preprocessing.image import ImageDataGenerator
from matplotlib import pyplot

from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D
from keras.layers import Activation, Dropout, Flatten, Dense
from keras import backend as K
from keras.models import Model

from keras.optimizers import RMSprop
from keras.optimizers import Adam

# pre-trained models
from tensorflow.keras.applications.vgg19 import VGG19
from keras.applications.vgg16 import VGG16
from keras.applications.inception_v3 import InceptionV3

from keras.layers import BatchNormalization as BatchNorm
import tensorflow as tf
import math

from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import plot_confusion_matrix
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import f1_score, precision_score, recall_score, accuracy_score

from learning_rate import decayed_learning_rate, decayed_learning_rate_tuned

np.random.seed(1)
tf.random.set_seed(1)

# dataset details
train_data_dir =      './Data/Online/online_pendigits/offline/train/'
validation_data_dir = './Data/Online/online_pendigits/offline/test/'
nb_train_samples = 7494
nb_validation_samples = 3498
num_classes = 10

epochs = 30
batch_size = 16
# dimensions of our images.
img_width, img_height = 32, 32
input_shape = (img_width, img_height, 3)

# using VGG16
# load model without classifier layers
model = Sequential()
# # create the VGG16 model with only the convolutional layers, and using weights from ImageNet
source_model = VGG16(include_top=False, input_shape=input_shape)

# mark loaded layers as not trainable
for layer in source_model.layers[:-6]:
    layer.trainable = False
    model.add(layer)

model.add(BatchNorm())
model.add(Flatten())
model.add(Dense(512, activation='relu'))
model.add(BatchNorm())
model.add(Dropout(0.35))
model.add(Dense(512, activation='relu'))
model.add(BatchNorm())
model.add(Dropout(0.35))
model.add(Dense(num_classes, activation='softmax'))

model.compile(loss='categorical_crossentropy', optimizer=keras.optimizers.RMSprop(), metrics=['accuracy'])
print(model.summary())

# this is the augmentation configuration we will use for training
train_datagen = ImageDataGenerator(
                    rescale=1.0/255,
                    rotation_range=5,
                    width_shift_range=0.05,
                    height_shift_range=0.05,
                    shear_range=0.5,
                    zoom_range=0.05,
            #         horizontal_flip=True,
                    fill_mode='constant',
                    cval = 0
                )

# this is the augmentation configuration we will use for testing:
# only rescaling for test dataset
test_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
    train_data_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    color_mode="rgb",
    class_mode='categorical',
#     subset='training',
    shuffle=True,
    seed=14)

validation_generator = test_datagen.flow_from_directory(
    validation_data_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    color_mode="rgb",
#     subset='validation',
    shuffle=False,
    class_mode='categorical')

# custom learning rate
callback = tf.keras.callbacks.LearningRateScheduler(decayed_learning_rate)

history1 = model.fit(
    train_generator,
    steps_per_epoch=nb_train_samples // batch_size,
    epochs=epochs,
    callbacks=[callback],
    validation_data=validation_generator,
    validation_steps=nb_validation_samples // batch_size)


# fine tuning the model
epochs = 20

# mark layers as trainable
for layer in model.layers[:12]:
    layer.trainable = True

train_generator.reset()
validation_generator.reset()

model.compile(loss='categorical_crossentropy', optimizer=keras.optimizers.RMSprop(), metrics=['accuracy'])
print(model.summary())

# custom learning rate
callback = tf.keras.callbacks.LearningRateScheduler(decayed_learning_rate_tuned)

history2 = model.fit(
    train_generator,
    steps_per_epoch=nb_train_samples // batch_size,
    epochs=epochs,
    callbacks=[callback],
    validation_data=validation_generator,
    validation_steps=nb_validation_samples // batch_size)

# model.save_weights('first_try0.h5')

# summarize history for accuracy
plt.plot(history1.history['accuracy']+history2.history['accuracy'])
plt.plot(history1.history['val_accuracy']+history2.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epochs')
plt.legend(['train', 'test'], loc='upper right')
plt.show()
# summarize history for loss
plt.plot(history1.history['loss']+history2.history['loss'])
plt.plot(history1.history['val_loss']+history2.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epochs')
plt.legend(['train', 'test'], loc='upper right')
plt.show()

filenames = validation_generator.filenames

predict = model.predict(validation_generator)
y_pred = np.argmax(predict,axis=-1)

cm = confusion_matrix(validation_generator.classes,y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
# disp = ConfusionMatrixDisplay(confusion_matrix=cm,
#                               display_labels=clf.classes_)

fig, ax = plt.subplots(figsize=(math.ceil(num_classes/3.0), math.ceil(num_classes/3.0)))
disp.plot(ax=ax, cmap=plt.cm.Blues)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# block1_conv1 (Conv2D)        (None, 32, 32, 64)        1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 32, 32, 64)        36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 16, 16, 64)        0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 16, 16, 128)       73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 16, 16, 128)       147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 8, 8, 128)         0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 8, 8, 256)         295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 8, 8, 256)         590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 8, 8, 256)         590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 4, 4, 256)         0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 4, 4, 512)         1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 4, 4, 512)         2359808
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 4, 4, 512)         2048
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 8192)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 512)               4194816
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 512)               2048
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 512)               262656
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 512)               2048
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 10)                5130
# =================================================================
# Total params: 9,744,202
# Trainable params: 4,465,674
# Non-trainable params: 5,278,528
# _________________________________________________________________
# None
# Found 7494 images belonging to 10 classes.
# Found 3498 images belonging to 10 classes.
# Epoch 1/30
# 468/468 [==============================] - 121s 258ms/step - loss: 3.2461 - accuracy: 0.1008 - val_loss: 2.7524 - val_accuracy: 0.0943 - lr: 5.0000e-05
# Epoch 2/30
# 468/468 [==============================] - 128s 274ms/step - loss: 3.0873 - accuracy: 0.1068 - val_loss: 2.7177 - val_accuracy: 0.1001 - lr: 5.0000e-05
# Epoch 3/30
# 468/468 [==============================] - 128s 274ms/step - loss: 2.9439 - accuracy: 0.1163 - val_loss: 2.6221 - val_accuracy: 0.0986 - lr: 5.0000e-05
# Epoch 4/30
# 468/468 [==============================] - 126s 269ms/step - loss: 2.9005 - accuracy: 0.1143 - val_loss: 2.5938 - val_accuracy: 0.0932 - lr: 5.0000e-05
# Epoch 5/30
# 468/468 [==============================] - 128s 273ms/step - loss: 2.8289 - accuracy: 0.1175 - val_loss: 2.5367 - val_accuracy: 0.1026 - lr: 5.0000e-05
# Epoch 6/30
# 468/468 [==============================] - 128s 274ms/step - loss: 2.8001 - accuracy: 0.1142 - val_loss: 2.5247 - val_accuracy: 0.1018 - lr: 5.0000e-05
# Epoch 7/30
# 468/468 [==============================] - 124s 266ms/step - loss: 2.7645 - accuracy: 0.1190 - val_loss: 2.5359 - val_accuracy: 0.1015 - lr: 5.0000e-05
# Epoch 8/30
# 468/468 [==============================] - 108s 231ms/step - loss: 2.7435 - accuracy: 0.1229 - val_loss: 2.5044 - val_accuracy: 0.1001 - lr: 5.0000e-05
# Epoch 9/30
# 468/468 [==============================] - 122s 260ms/step - loss: 2.7083 - accuracy: 0.1237 - val_loss: 2.5996 - val_accuracy: 0.0963 - lr: 5.0000e-05
# Epoch 10/30
# 468/468 [==============================] - 116s 249ms/step - loss: 2.6659 - accuracy: 0.1316 - val_loss: 2.4745 - val_accuracy: 0.0992 - lr: 5.0000e-05
# Epoch 11/30
# 468/468 [==============================] - 119s 254ms/step - loss: 2.6093 - accuracy: 0.1341 - val_loss: 2.4624 - val_accuracy: 0.1024 - lr: 1.0000e-05
# Epoch 12/30
# 468/468 [==============================] - 116s 247ms/step - loss: 2.6224 - accuracy: 0.1293 - val_loss: 2.4602 - val_accuracy: 0.0966 - lr: 1.0000e-05
# Epoch 13/30
# 468/468 [==============================] - 121s 258ms/step - loss: 2.6046 - accuracy: 0.1427 - val_loss: 2.4603 - val_accuracy: 0.0969 - lr: 1.0000e-05
# Epoch 14/30
# 468/468 [==============================] - 123s 262ms/step - loss: 2.5994 - accuracy: 0.1365 - val_loss: 2.4570 - val_accuracy: 0.0983 - lr: 1.0000e-05
# Epoch 15/30
# 468/468 [==============================] - 117s 250ms/step - loss: 2.5784 - accuracy: 0.1353 - val_loss: 2.4614 - val_accuracy: 0.1015 - lr: 1.0000e-05
# Epoch 16/30
# 468/468 [==============================] - 122s 260ms/step - loss: 2.5821 - accuracy: 0.1423 - val_loss: 2.4560 - val_accuracy: 0.0989 - lr: 1.0000e-05
# Epoch 17/30
# 468/468 [==============================] - 118s 252ms/step - loss: 2.5970 - accuracy: 0.1387 - val_loss: 2.4557 - val_accuracy: 0.0975 - lr: 8.0000e-06
# Epoch 18/30
# 468/468 [==============================] - 115s 246ms/step - loss: 2.5943 - accuracy: 0.1393 - val_loss: 2.4557 - val_accuracy: 0.0978 - lr: 8.0000e-06
# Epoch 19/30
# 468/468 [==============================] - 121s 259ms/step - loss: 2.5475 - accuracy: 0.1472 - val_loss: 2.4581 - val_accuracy: 0.0972 - lr: 8.0000e-06
# Epoch 20/30
# 468/468 [==============================] - 124s 265ms/step - loss: 2.5716 - accuracy: 0.1419 - val_loss: 2.4592 - val_accuracy: 0.0935 - lr: 8.0000e-06
# Epoch 21/30
# 468/468 [==============================] - 99s 212ms/step - loss: 2.5415 - accuracy: 0.1404 - val_loss: 2.4590 - val_accuracy: 0.0989 - lr: 8.0000e-06
# Epoch 22/30
# 468/468 [==============================] - 119s 253ms/step - loss: 2.5564 - accuracy: 0.1341 - val_loss: 2.4614 - val_accuracy: 0.0983 - lr: 8.0000e-06
# Epoch 23/30
# 468/468 [==============================] - 112s 239ms/step - loss: 2.5270 - accuracy: 0.1450 - val_loss: 2.4653 - val_accuracy: 0.0909 - lr: 8.0000e-06
# Epoch 24/30
# 468/468 [==============================] - 111s 237ms/step - loss: 2.5572 - accuracy: 0.1381 - val_loss: 2.4702 - val_accuracy: 0.0992 - lr: 8.0000e-06
# Epoch 25/30
# 468/468 [==============================] - 119s 255ms/step - loss: 2.5322 - accuracy: 0.1413 - val_loss: 2.4653 - val_accuracy: 0.1015 - lr: 8.0000e-06
# Epoch 26/30
# 468/468 [==============================] - 121s 259ms/step - loss: 2.5399 - accuracy: 0.1436 - val_loss: 2.4624 - val_accuracy: 0.0978 - lr: 8.0000e-06
# Epoch 27/30
# 468/468 [==============================] - 122s 260ms/step - loss: 2.5321 - accuracy: 0.1502 - val_loss: 2.4698 - val_accuracy: 0.0989 - lr: 8.0000e-06
# Epoch 28/30
# 468/468 [==============================] - 118s 253ms/step - loss: 2.5321 - accuracy: 0.1450 - val_loss: 2.4653 - val_accuracy: 0.0952 - lr: 8.0000e-06
# Epoch 29/30
# 468/468 [==============================] - 118s 252ms/step - loss: 2.5299 - accuracy: 0.1424 - val_loss: 2.4636 - val_accuracy: 0.0903 - lr: 8.0000e-06
# Epoch 30/30
# 468/468 [==============================] - 122s 261ms/step - loss: 2.5140 - accuracy: 0.1534 - val_loss: 2.4706 - val_accuracy: 0.0932 - lr: 8.0000e-06
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# block1_conv1 (Conv2D)        (None, 32, 32, 64)        1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 32, 32, 64)        36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 16, 16, 64)        0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 16, 16, 128)       73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 16, 16, 128)       147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 8, 8, 128)         0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 8, 8, 256)         295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 8, 8, 256)         590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 8, 8, 256)         590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 4, 4, 256)         0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 4, 4, 512)         1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 4, 4, 512)         2359808
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 4, 4, 512)         2048
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 8192)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 512)               4194816
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 512)               2048
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 512)               262656
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 512)               2048
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 10)                5130
# =================================================================
# Total params: 9,744,202
# Trainable params: 9,741,130
# Non-trainable params: 3,072
# _________________________________________________________________
# None
# Epoch 1/20
# 468/468 [==============================] - 287s 613ms/step - loss: 2.5159 - accuracy: 0.1499 - val_loss: 2.4741 - val_accuracy: 0.0949 - lr: 1.0000e-07
# Epoch 2/20
# 468/468 [==============================] - 297s 635ms/step - loss: 2.5149 - accuracy: 0.1499 - val_loss: 2.4765 - val_accuracy: 0.0958 - lr: 1.0000e-07
# Epoch 3/20
# 468/468 [==============================] - 296s 633ms/step - loss: 2.5206 - accuracy: 0.1484 - val_loss: 2.4699 - val_accuracy: 0.0963 - lr: 1.0000e-07
# Epoch 4/20
# 468/468 [==============================] - 293s 626ms/step - loss: 2.4946 - accuracy: 0.1522 - val_loss: 2.4713 - val_accuracy: 0.0975 - lr: 1.0000e-07
# Epoch 5/20
# 468/468 [==============================] - 292s 624ms/step - loss: 2.4782 - accuracy: 0.1518 - val_loss: 2.4694 - val_accuracy: 0.0972 - lr: 1.0000e-07
# Epoch 6/20
# 468/468 [==============================] - 307s 657ms/step - loss: 2.5229 - accuracy: 0.1514 - val_loss: 2.4848 - val_accuracy: 0.0995 - lr: 5.0000e-06
# Epoch 7/20
# 468/468 [==============================] - 311s 665ms/step - loss: 2.5140 - accuracy: 0.1496 - val_loss: 2.4585 - val_accuracy: 0.0966 - lr: 5.0000e-06
# Epoch 8/20
# 468/468 [==============================] - 295s 629ms/step - loss: 2.5017 - accuracy: 0.1522 - val_loss: 2.5112 - val_accuracy: 0.0992 - lr: 5.0000e-06
# Epoch 9/20
# 468/468 [==============================] - 282s 602ms/step - loss: 2.5079 - accuracy: 0.1494 - val_loss: 2.4778 - val_accuracy: 0.0983 - lr: 5.0000e-06
# Epoch 10/20
# 468/468 [==============================] - 211s 450ms/step - loss: 2.5062 - accuracy: 0.1511 - val_loss: 2.4854 - val_accuracy: 0.0998 - lr: 5.0000e-06
# Epoch 11/20
# 468/468 [==============================] - 206s 440ms/step - loss: 2.5036 - accuracy: 0.1539 - val_loss: 2.5058 - val_accuracy: 0.1001 - lr: 5.0000e-06
# Epoch 12/20
# 468/468 [==============================] - 203s 434ms/step - loss: 2.4863 - accuracy: 0.1557 - val_loss: 2.4948 - val_accuracy: 0.0955 - lr: 3.0000e-06
# Epoch 13/20
# 468/468 [==============================] - 201s 430ms/step - loss: 2.4987 - accuracy: 0.1539 - val_loss: 2.4848 - val_accuracy: 0.0992 - lr: 3.0000e-06
# Epoch 14/20
# 468/468 [==============================] - 214s 457ms/step - loss: 2.4917 - accuracy: 0.1627 - val_loss: 2.5105 - val_accuracy: 0.0946 - lr: 3.0000e-06
# Epoch 15/20
# 468/468 [==============================] - 213s 455ms/step - loss: 2.4696 - accuracy: 0.1660 - val_loss: 2.5030 - val_accuracy: 0.0943 - lr: 3.0000e-06
# Epoch 16/20
# 468/468 [==============================] - 218s 466ms/step - loss: 2.4807 - accuracy: 0.1615 - val_loss: 2.4941 - val_accuracy: 0.0955 - lr: 3.0000e-06
# Epoch 17/20
# 468/468 [==============================] - 218s 466ms/step - loss: 2.4746 - accuracy: 0.1569 - val_loss: 2.5031 - val_accuracy: 0.0943 - lr: 2.0000e-06
# Epoch 18/20
# 468/468 [==============================] - 214s 458ms/step - loss: 2.4522 - accuracy: 0.1664 - val_loss: 2.4952 - val_accuracy: 0.0986 - lr: 2.0000e-06
# Epoch 19/20
# 468/468 [==============================] - 207s 443ms/step - loss: 2.4663 - accuracy: 0.1602 - val_loss: 2.5013 - val_accuracy: 0.0966 - lr: 2.0000e-06
# Epoch 20/20
# 468/468 [==============================] - 211s 450ms/step - loss: 2.4756 - accuracy: 0.1545 - val_loss: 2.4998 - val_accuracy: 0.0966 - lr: 2.0000e-06

# %%
print('precision_score: ', precision_score(validation_generator.classes,y_pred, average="macro"))
print('recall_score   : ', recall_score(validation_generator.classes,y_pred, average="macro"))
print('f1_score       : ', f1_score(validation_generator.classes,y_pred, average="macro"))
print('accuracy_score : ', accuracy_score(validation_generator.classes,y_pred, normalize=True))

print("\nBest accuracy  : ", max(max(history1.history['val_accuracy']), max(history2.history['val_accuracy'])))
# Out:
# precision_score:  0.09676652703902898
# recall_score   :  0.09612252375478515
# f1_score       :  0.09459423516412577
# accuracy_score :  0.0963407661520869
#
# Best accuracy  :  0.10263761132955551

# %%
# with fine tuning
import os
import numpy as np
import matplotlib.pyplot as plt
import glob

# %matplotlib inline

# example of horizontal shift image augmentation
from numpy import expand_dims
from tensorflow import keras
from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array
from keras.preprocessing.image import ImageDataGenerator
from matplotlib import pyplot

from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D
from keras.layers import Activation, Dropout, Flatten, Dense
from keras import backend as K
from keras.models import Model

from keras.optimizers import RMSprop
from keras.optimizers import Adam

# pre-trained models
from tensorflow.keras.applications.vgg19 import VGG19
from keras.applications.vgg16 import VGG16
from keras.applications.inception_v3 import InceptionV3

from keras.layers import BatchNormalization as BatchNorm
import tensorflow as tf
import math

from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import plot_confusion_matrix
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import f1_score, precision_score, recall_score, accuracy_score

from learning_rate import decayed_learning_rate, decayed_learning_rate_tuned

np.random.seed(1)
tf.random.set_seed(1)

# dataset details
train_data_dir =      './Data/Online/online_pendigits/offline/train/'
validation_data_dir = './Data/Online/online_pendigits/offline/test/'
nb_train_samples = 7494
nb_validation_samples = 3498
num_classes = 10

epochs = 30
batch_size = 16
# dimensions of our images.
img_width, img_height = 32, 32
input_shape = (img_width, img_height, 3)

# using VGG16
# load model without classifier layers
model = Sequential()
# # create the VGG16 model with only the convolutional layers, and using weights from ImageNet
source_model = VGG16(include_top=False, input_shape=input_shape)

# mark loaded layers as not trainable
for layer in source_model.layers[:-6]:
    layer.trainable = False
    model.add(layer)

model.add(BatchNorm())
model.add(Flatten())
model.add(Dense(512, activation='relu'))
model.add(BatchNorm())
model.add(Dropout(0.35))
model.add(Dense(512, activation='relu'))
model.add(BatchNorm())
model.add(Dropout(0.35))
model.add(Dense(num_classes, activation='softmax'))

model.compile(loss='categorical_crossentropy', optimizer=keras.optimizers.RMSprop(), metrics=['accuracy'])
print(model.summary())

# this is the augmentation configuration we will use for training
train_datagen = ImageDataGenerator(
                    rescale=1.0/255,
                    rotation_range=5,
                    width_shift_range=0.05,
                    height_shift_range=0.05,
                    shear_range=0.5,
                    zoom_range=0.05,
            #         horizontal_flip=True,
                    fill_mode='constant',
                    cval = 0
                )

# this is the augmentation configuration we will use for testing:
# only rescaling for test dataset
test_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
    train_data_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    color_mode="rgb",
    class_mode='categorical',
#     subset='training',
    shuffle=True,
    seed=15)

validation_generator = test_datagen.flow_from_directory(
    validation_data_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    color_mode="rgb",
#     subset='validation',
    shuffle=False,
    class_mode='categorical')

# custom learning rate
callback = tf.keras.callbacks.LearningRateScheduler(decayed_learning_rate)

history1 = model.fit(
    train_generator,
    steps_per_epoch=nb_train_samples // batch_size,
    epochs=epochs,
    callbacks=[callback],
    validation_data=validation_generator,
    validation_steps=nb_validation_samples // batch_size)


# fine tuning the model
epochs = 20

# mark layers as trainable
for layer in model.layers[:12]:
    layer.trainable = True

train_generator.reset()
validation_generator.reset()

model.compile(loss='categorical_crossentropy', optimizer=keras.optimizers.RMSprop(), metrics=['accuracy'])
print(model.summary())

# custom learning rate
callback = tf.keras.callbacks.LearningRateScheduler(decayed_learning_rate_tuned)

history2 = model.fit(
    train_generator,
    steps_per_epoch=nb_train_samples // batch_size,
    epochs=epochs,
    callbacks=[callback],
    validation_data=validation_generator,
    validation_steps=nb_validation_samples // batch_size)

# model.save_weights('first_try0.h5')

# summarize history for accuracy
plt.plot(history1.history['accuracy']+history2.history['accuracy'])
plt.plot(history1.history['val_accuracy']+history2.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epochs')
plt.legend(['train', 'test'], loc='upper right')
plt.show()
# summarize history for loss
plt.plot(history1.history['loss']+history2.history['loss'])
plt.plot(history1.history['val_loss']+history2.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epochs')
plt.legend(['train', 'test'], loc='upper right')
plt.show()

filenames = validation_generator.filenames

predict = model.predict(validation_generator)
y_pred = np.argmax(predict,axis=-1)

cm = confusion_matrix(validation_generator.classes,y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
# disp = ConfusionMatrixDisplay(confusion_matrix=cm,
#                               display_labels=clf.classes_)

fig, ax = plt.subplots(figsize=(math.ceil(num_classes/3.0), math.ceil(num_classes/3.0)))
disp.plot(ax=ax, cmap=plt.cm.Blues)
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# block1_conv1 (Conv2D)        (None, 32, 32, 64)        1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 32, 32, 64)        36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 16, 16, 64)        0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 16, 16, 128)       73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 16, 16, 128)       147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 8, 8, 128)         0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 8, 8, 256)         295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 8, 8, 256)         590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 8, 8, 256)         590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 4, 4, 256)         0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 4, 4, 512)         1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 4, 4, 512)         2359808
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 4, 4, 512)         2048
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 8192)              0
# _________________________________________________________________
# dense_6 (Dense)              (None, 512)               4194816
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 512)               2048
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_7 (Dense)              (None, 512)               262656
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 512)               2048
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_8 (Dense)              (None, 10)                5130
# =================================================================
# Total params: 9,744,202
# Trainable params: 4,465,674
# Non-trainable params: 5,278,528
# _________________________________________________________________
# None
# Found 7494 images belonging to 10 classes.
# Found 3498 images belonging to 10 classes.
# Epoch 1/30
# 468/468 [==============================] - 83s 177ms/step - loss: 3.2611 - accuracy: 0.0963 - val_loss: 2.7752 - val_accuracy: 0.1026 - lr: 5.0000e-05
# Epoch 2/30
# 468/468 [==============================] - 83s 177ms/step - loss: 3.0692 - accuracy: 0.1130 - val_loss: 2.6284 - val_accuracy: 0.1041 - lr: 5.0000e-05
# Epoch 3/30
# 468/468 [==============================] - 87s 186ms/step - loss: 2.9565 - accuracy: 0.1115 - val_loss: 2.5877 - val_accuracy: 0.0978 - lr: 5.0000e-05
# Epoch 4/30
# 468/468 [==============================] - 86s 183ms/step - loss: 2.8872 - accuracy: 0.1162 - val_loss: 2.5725 - val_accuracy: 0.0986 - lr: 5.0000e-05
# Epoch 5/30
# 468/468 [==============================] - 83s 177ms/step - loss: 2.8356 - accuracy: 0.1146 - val_loss: 2.5561 - val_accuracy: 0.0894 - lr: 5.0000e-05
# Epoch 6/30
# 468/468 [==============================] - 86s 184ms/step - loss: 2.7920 - accuracy: 0.1248 - val_loss: 2.5244 - val_accuracy: 0.0943 - lr: 5.0000e-05
# Epoch 7/30
# 468/468 [==============================] - 85s 182ms/step - loss: 2.7710 - accuracy: 0.1230 - val_loss: 2.5018 - val_accuracy: 0.0992 - lr: 5.0000e-05
# Epoch 8/30
# 468/468 [==============================] - 77s 165ms/step - loss: 2.7007 - accuracy: 0.1284 - val_loss: 2.4793 - val_accuracy: 0.0986 - lr: 5.0000e-05
# Epoch 9/30
#  12/468 [..............................] - ETA: 42s - loss: 2.6335 - accuracy: 0.1406
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-652a5f3ebc45> in <module>
#     126     callbacks=[callback],
#     127     validation_data=validation_generator,
# --> 128     validation_steps=nb_validation_samples // batch_size)
#     129
#     130
#
# ~/anaconda3/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py in _method_wrapper(self, *args, **kwargs)
#      64   def _method_wrapper(self, *args, **kwargs):
#      65     if not self._in_multi_worker_mode():  # pylint: disable=protected-access
# ---> 66       return method(self, *args, **kwargs)
#      67
#      68     # Running inside `run_distribute_coordinator` already.
#
# ~/anaconda3/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#     846                 batch_size=batch_size):
#     847               callbacks.on_train_batch_begin(step)
# --> 848               tmp_logs = train_function(iterator)
#     849               # Catch OutOfRangeError for Datasets of unknown size.
#     850               # This blocks until the batch has finished executing.
#
# ~/anaconda3/lib/python3.7/site-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     578         xla_context.Exit()
#     579     else:
# --> 580       result = self._call(*args, **kwds)
#     581
#     582     if tracing_count == self._get_tracing_count():
#
# ~/anaconda3/lib/python3.7/site-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     609       # In this case we have created variables on the first call, so we run the
#     610       # defunned version which is guaranteed to never create variables.
# --> 611       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     612     elif self._stateful_fn is not None:
#     613       # Release the lock early so that multiple threads can perform the call
#
# ~/anaconda3/lib/python3.7/site-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    2418     with self._lock:
#    2419       graph_function, args, kwargs = self._maybe_define_function(args, kwargs)
# -> 2420     return graph_function._filtered_call(args, kwargs)  # pylint: disable=protected-access
#    2421
#    2422   @property
#
# ~/anaconda3/lib/python3.7/site-packages/tensorflow/python/eager/function.py in _filtered_call(self, args, kwargs)
#    1663          if isinstance(t, (ops.Tensor,
#    1664                            resource_variable_ops.BaseResourceVariable))),
# -> 1665         self.captured_inputs)
#    1666
#    1667   def _call_flat(self, args, captured_inputs, cancellation_manager=None):
#
# ~/anaconda3/lib/python3.7/site-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1744       # No tape is watching; skip to running the function.
#    1745       return self._build_call_outputs(self._inference_function.call(
# -> 1746           ctx, args, cancellation_manager=cancellation_manager))
#    1747     forward_backward = self._select_forward_and_backward_functions(
#    1748         args,
#
# ~/anaconda3/lib/python3.7/site-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     596               inputs=args,
#     597               attrs=attrs,
# --> 598               ctx=ctx)
#     599         else:
#     600           outputs = execute.execute_with_cancellation(
#
# ~/anaconda3/lib/python3.7/site-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      58     ctx.ensure_initialized()
#      59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#      62     if name is not None:
#
# KeyboardInterrupt:

# %%
print('precision_score: ', precision_score(validation_generator.classes,y_pred, average="macro"))
print('recall_score   : ', recall_score(validation_generator.classes,y_pred, average="macro"))
print('f1_score       : ', f1_score(validation_generator.classes,y_pred, average="macro"))
print('accuracy_score : ', accuracy_score(validation_generator.classes,y_pred, normalize=True))

print("\nBest accuracy  : ", max(max(history1.history['val_accuracy']), max(history2.history['val_accuracy'])))

# %%
# with fine tuning
import os
import numpy as np
import matplotlib.pyplot as plt
import glob

# %matplotlib inline

# example of horizontal shift image augmentation
from numpy import expand_dims
from tensorflow import keras
from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array
from keras.preprocessing.image import ImageDataGenerator
from matplotlib import pyplot

from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D
from keras.layers import Activation, Dropout, Flatten, Dense
from keras import backend as K
from keras.models import Model

from keras.optimizers import RMSprop
from keras.optimizers import Adam

# pre-trained models
from tensorflow.keras.applications.vgg19 import VGG19
from keras.applications.vgg16 import VGG16
from keras.applications.inception_v3 import InceptionV3

from keras.layers import BatchNormalization as BatchNorm
import tensorflow as tf
import math

from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import plot_confusion_matrix
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import f1_score, precision_score, recall_score, accuracy_score

from learning_rate import decayed_learning_rate, decayed_learning_rate_tuned

np.random.seed(1)
tf.random.set_seed(1)

# dataset details
train_data_dir =      './Data/Online/online_pendigits/offline/train/'
validation_data_dir = './Data/Online/online_pendigits/offline/test/'
nb_train_samples = 7494
nb_validation_samples = 3498
num_classes = 10

epochs = 30
batch_size = 16
# dimensions of our images.
img_width, img_height = 32, 32
input_shape = (img_width, img_height, 3)

# using VGG16
# load model without classifier layers
model = Sequential()
# # create the VGG16 model with only the convolutional layers, and using weights from ImageNet
source_model = VGG16(include_top=False, input_shape=input_shape)

# mark loaded layers as not trainable
for layer in source_model.layers[:-6]:
    layer.trainable = False
    model.add(layer)

model.add(BatchNorm())
model.add(Flatten())
model.add(Dense(512, activation='relu'))
model.add(BatchNorm())
model.add(Dropout(0.35))
model.add(Dense(512, activation='relu'))
model.add(BatchNorm())
model.add(Dropout(0.35))
model.add(Dense(num_classes, activation='softmax'))

model.compile(loss='categorical_crossentropy', optimizer=keras.optimizers.RMSprop(), metrics=['accuracy'])
print(model.summary())

# this is the augmentation configuration we will use for training
train_datagen = ImageDataGenerator(
                    rescale=1.0/255,
                    rotation_range=5,
                    width_shift_range=0.05,
                    height_shift_range=0.05,
                    shear_range=0.5,
                    zoom_range=0.05,
            #         horizontal_flip=True,
                    fill_mode='constant',
                    cval = 0
                )

# this is the augmentation configuration we will use for testing:
# only rescaling for test dataset
test_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
    train_data_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    color_mode="rgb",
    class_mode='categorical',
#     subset='training',
    shuffle=True,
    seed=16)

validation_generator = test_datagen.flow_from_directory(
    validation_data_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    color_mode="rgb",
#     subset='validation',
    shuffle=False,
    class_mode='categorical')

# custom learning rate
callback = tf.keras.callbacks.LearningRateScheduler(decayed_learning_rate)

history1 = model.fit(
    train_generator,
    steps_per_epoch=nb_train_samples // batch_size,
    epochs=epochs,
    callbacks=[callback],
    validation_data=validation_generator,
    validation_steps=nb_validation_samples // batch_size)


# fine tuning the model
epochs = 20

# mark layers as trainable
for layer in model.layers[:12]:
    layer.trainable = True

train_generator.reset()
validation_generator.reset()

model.compile(loss='categorical_crossentropy', optimizer=keras.optimizers.RMSprop(), metrics=['accuracy'])
print(model.summary())

# custom learning rate
callback = tf.keras.callbacks.LearningRateScheduler(decayed_learning_rate_tuned)

history2 = model.fit(
    train_generator,
    steps_per_epoch=nb_train_samples // batch_size,
    epochs=epochs,
    callbacks=[callback],
    validation_data=validation_generator,
    validation_steps=nb_validation_samples // batch_size)

# model.save_weights('first_try0.h5')

# summarize history for accuracy
plt.plot(history1.history['accuracy']+history2.history['accuracy'])
plt.plot(history1.history['val_accuracy']+history2.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epochs')
plt.legend(['train', 'test'], loc='upper right')
plt.show()
# summarize history for loss
plt.plot(history1.history['loss']+history2.history['loss'])
plt.plot(history1.history['val_loss']+history2.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epochs')
plt.legend(['train', 'test'], loc='upper right')
plt.show()

filenames = validation_generator.filenames

predict = model.predict(validation_generator)
y_pred = np.argmax(predict,axis=-1)

cm = confusion_matrix(validation_generator.classes,y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
# disp = ConfusionMatrixDisplay(confusion_matrix=cm,
#                               display_labels=clf.classes_)

fig, ax = plt.subplots(figsize=(math.ceil(num_classes/3.0), math.ceil(num_classes/3.0)))
disp.plot(ax=ax, cmap=plt.cm.Blues)

# %%
print('precision_score: ', precision_score(validation_generator.classes,y_pred, average="macro"))
print('recall_score   : ', recall_score(validation_generator.classes,y_pred, average="macro"))
print('f1_score       : ', f1_score(validation_generator.classes,y_pred, average="macro"))
print('accuracy_score : ', accuracy_score(validation_generator.classes,y_pred, normalize=True))

print("\nBest accuracy  : ", max(max(history1.history['val_accuracy']), max(history2.history['val_accuracy'])))

# %%
# with fine tuning
import os
import numpy as np
import matplotlib.pyplot as plt
import glob

# %matplotlib inline

# example of horizontal shift image augmentation
from numpy import expand_dims
from tensorflow import keras
from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array
from keras.preprocessing.image import ImageDataGenerator
from matplotlib import pyplot

from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D
from keras.layers import Activation, Dropout, Flatten, Dense
from keras import backend as K
from keras.models import Model

from keras.optimizers import RMSprop
from keras.optimizers import Adam

# pre-trained models
from tensorflow.keras.applications.vgg19 import VGG19
from keras.applications.vgg16 import VGG16
from keras.applications.inception_v3 import InceptionV3

from keras.layers import BatchNormalization as BatchNorm
import tensorflow as tf
import math

from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import plot_confusion_matrix
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import f1_score, precision_score, recall_score, accuracy_score

from learning_rate import decayed_learning_rate, decayed_learning_rate_tuned

np.random.seed(1)
tf.random.set_seed(1)

# dataset details
train_data_dir =      './Data/Online/online_pendigits/offline/train/'
validation_data_dir = './Data/Online/online_pendigits/offline/test/'
nb_train_samples = 7494
nb_validation_samples = 3498
num_classes = 10

epochs = 30
batch_size = 16
# dimensions of our images.
img_width, img_height = 32, 32
input_shape = (img_width, img_height, 3)

# using VGG16
# load model without classifier layers
model = Sequential()
# # create the VGG16 model with only the convolutional layers, and using weights from ImageNet
source_model = VGG16(include_top=False, input_shape=input_shape)

# mark loaded layers as not trainable
for layer in source_model.layers[:-6]:
    layer.trainable = False
    model.add(layer)

model.add(BatchNorm())
model.add(Flatten())
model.add(Dense(512, activation='relu'))
model.add(BatchNorm())
model.add(Dropout(0.35))
model.add(Dense(512, activation='relu'))
model.add(BatchNorm())
model.add(Dropout(0.35))
model.add(Dense(num_classes, activation='softmax'))

model.compile(loss='categorical_crossentropy', optimizer=keras.optimizers.RMSprop(), metrics=['accuracy'])
print(model.summary())

# this is the augmentation configuration we will use for training
train_datagen = ImageDataGenerator(
                    rescale=1.0/255,
                    rotation_range=5,
                    width_shift_range=0.05,
                    height_shift_range=0.05,
                    shear_range=0.5,
                    zoom_range=0.05,
            #         horizontal_flip=True,
                    fill_mode='constant',
                    cval = 0
                )

# this is the augmentation configuration we will use for testing:
# only rescaling for test dataset
test_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
    train_data_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    color_mode="rgb",
    class_mode='categorical',
#     subset='training',
    shuffle=True,
    seed=17)

validation_generator = test_datagen.flow_from_directory(
    validation_data_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    color_mode="rgb",
#     subset='validation',
    shuffle=False,
    class_mode='categorical')

# custom learning rate
callback = tf.keras.callbacks.LearningRateScheduler(decayed_learning_rate)

history1 = model.fit(
    train_generator,
    steps_per_epoch=nb_train_samples // batch_size,
    epochs=epochs,
    callbacks=[callback],
    validation_data=validation_generator,
    validation_steps=nb_validation_samples // batch_size)


# fine tuning the model
epochs = 20

# mark layers as trainable
for layer in model.layers[:12]:
    layer.trainable = True

train_generator.reset()
validation_generator.reset()

model.compile(loss='categorical_crossentropy', optimizer=keras.optimizers.RMSprop(), metrics=['accuracy'])
print(model.summary())

# custom learning rate
callback = tf.keras.callbacks.LearningRateScheduler(decayed_learning_rate_tuned)

history2 = model.fit(
    train_generator,
    steps_per_epoch=nb_train_samples // batch_size,
    epochs=epochs,
    callbacks=[callback],
    validation_data=validation_generator,
    validation_steps=nb_validation_samples // batch_size)

# model.save_weights('first_try0.h5')

# summarize history for accuracy
plt.plot(history1.history['accuracy']+history2.history['accuracy'])
plt.plot(history1.history['val_accuracy']+history2.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epochs')
plt.legend(['train', 'test'], loc='upper right')
plt.show()
# summarize history for loss
plt.plot(history1.history['loss']+history2.history['loss'])
plt.plot(history1.history['val_loss']+history2.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epochs')
plt.legend(['train', 'test'], loc='upper right')
plt.show()

filenames = validation_generator.filenames

predict = model.predict(validation_generator)
y_pred = np.argmax(predict,axis=-1)

cm = confusion_matrix(validation_generator.classes,y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
# disp = ConfusionMatrixDisplay(confusion_matrix=cm,
#                               display_labels=clf.classes_)

fig, ax = plt.subplots(figsize=(math.ceil(num_classes/3.0), math.ceil(num_classes/3.0)))
disp.plot(ax=ax, cmap=plt.cm.Blues)

# %%
print('precision_score: ', precision_score(validation_generator.classes,y_pred, average="macro"))
print('recall_score   : ', recall_score(validation_generator.classes,y_pred, average="macro"))
print('f1_score       : ', f1_score(validation_generator.classes,y_pred, average="macro"))
print('accuracy_score : ', accuracy_score(validation_generator.classes,y_pred, normalize=True))

print("\nBest accuracy  : ", max(max(history1.history['val_accuracy']), max(history2.history['val_accuracy'])))
